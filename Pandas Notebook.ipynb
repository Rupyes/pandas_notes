# %% [markdown]
# 1. To run terminal commands in notebook, add "!" in front of command. Eg: !ls

# %%
import pandas as pd
df = pd.read_csv("mobile_data.csv")

# %% [markdown]
# Showing all/maximum columns of the dataset in case of not being showed.

# %%
# maximun columns that will be shown is 41 in this case
pd.set_option("display.max_columns", 41)

# %%
df.head()
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
# 4         1         1        55   234.0            385                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  screen_size  \
# 0       10.5           5                     2.00           0          4.5
# 1       10.6           5                     0.30           1          4.0
# 2        8.5           5                     2.00           3          5.0
# 3        8.0           5                     2.00           3          5.0
# 4        7.9           5                     1.92           3          5.0
#
#    frames_per_second  FM  no_of_reviews_in_gsmarena_in_week  os  phone_height  \
# 0                 15   3                                  0   0         132.9
# 1                 30   2                                  6   0         124.5
# 2                 30   2                                 20   0         145.5
# 3                 15   3                                  0   0         147.5
# 4                 15   3                                  0   0         179.0
#
#    screen_protection  sim_size  price  talk_time  video_resolution  \
# 0                 26         3   3870          9               480
# 1                 26         5   4059          9               720
# 2                  4         3   4777         10              1080
# 3                 26         3   5799         19               720
# 4                 18         3   5990         11               720
#
#    display_resolution  removable_battery  display_type  \
# 0                  12                  3            11
# 1                  15                  3            11
# 2                   4                  3             1
# 3                  17                  3             2
# 4                  17                  3             1
#
#    primary_camera_resolution  battery_type  ram_memory  internal_memory  \
# 0                       5.00             1           1                7
# 1                       5.00             1           1                7
# 2                       5.04             2           1                7
# 3                       5.00             1           1                7
# 4                       5.00             1           1                7
#
#    brand_rank  no_of_cores  micro_sd_slot  screen_pixel_density  \
# 0          29            6              4                     2
# 1          11            6              4                     4
# 2          27            6              4                     9
# 3           4            6              4                     1
# 4           4            6              4                     1
#
#    water_proof_rate  phone_width  expandable_memory  version  usb_type  \
# 0                 3         67.8               64.0        5         3
# 1                 6         64.0               32.0        5         3
# 2                 6         72.0               32.0        6         3
# 3                 3         75.1               32.0        6         3
# 4                 6         91.0               32.0        6         3
#
#    battery_capacity  processor_rank  is_liked
# 0              2000             125         1
# 1              2000             165         1
# 2              2500             164         0
# 3              3000             165         1
# 4              3000             165         0

# %% [markdown]
# To print all misssing values of each and every columns of dataset

# %%
df.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               0
# stand_by_time                        0
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    0
# os                                   0
# phone_height                         0
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            0
# video_resolution                     0
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# primary_camera_resolution            0
# battery_type                         0
# ram_memory                           0
# internal_memory                      0
# brand_rank                           0
# no_of_cores                          0
# micro_sd_slot                        0
# screen_pixel_density                 0
# water_proof_rate                     0
# phone_width                          0
# expandable_memory                    0
# version                              0
# usb_type                             0
# battery_capacity                     0
# processor_rank                       0
# is_liked                             0
# dtype: int64

# %% [markdown]
# To print the datatypes
